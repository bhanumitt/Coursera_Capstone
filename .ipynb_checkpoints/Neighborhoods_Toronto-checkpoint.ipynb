# %% [markdown]
# ## Toronto Neighborhood Analysis

# %% [markdown]
# Importing all the required libraries!

# %%
import requests
import lxml.html as lh
import pandas as pd
from pandas.io.json import json_normalize
from sklearn.cluster import KMeans
import folium
from IPython.display import display

# %% [markdown]
# Using the requests library to get the HTML content from the wikipedia webpage and then extracting all the data which are in the **tr** block of the HTML as those are the rows of the table.

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
toronto_page = requests.get(URL)

doc = lh.fromstring(toronto_page.content)

rows = doc.xpath('//tr')

# %% [markdown]
# The first row in the extracted rows is the name of columns. So extracting it and storing it in a list.

# %%
cols = []

for column in rows[0]:
    cols.append(column.text_content()[:-1])
    
cols
# Out:
# ['Postal Code', 'Borough', 'Neighborhood']

# %% [markdown]
# Getting all other rows and storing it in the list variable named _'data'_.

# %%
data = []

for index, r in enumerate(rows):
    if index > 0 and index < 181:    # Index 180 marks the end of the table. 
        row = []
        for value in r:
            row.append(value.text_content()[:-1])
        data.append(row)

# %% [markdown]
# The **data** list is converted to a pandas dataframe and every _Borough_ which is _Not assigned_ is removed from the dataframe.

# %%
toronto_neighborhood = pd.DataFrame(data, columns=cols)
toronto_neighborhood = toronto_neighborhood[toronto_neighborhood['Borough'] != 'Not assigned'].reset_index(drop=True)

toronto_neighborhood.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
toronto_neighborhood.shape
# Out:
# (103, 3)

# %%
print(toronto_neighborhood['Postal Code'].nunique())
print("-----------------")
print(toronto_neighborhood[toronto_neighborhood['Neighborhood'] == 'Not assigned'].count())
# Out:
# 103
# -----------------
# Postal Code     0
# Borough         0
# Neighborhood    0
# dtype: int64

# %% [markdown]
# As there are total 103 rows in the table and also 103 unique values of postal codes, so there are no two postal codes which are the same. Also, there are no neighborhoods with **Not assigned** entry.
#
# Downloading the geodata of toronto neighborhoods!

# %%
# !wget http://cocl.us/Geospatial_data
# Out:
# --2020-07-02 12:49:57--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 161.202.50.39
# Connecting to cocl.us (cocl.us)|161.202.50.39|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2020-07-02 12:49:57--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|161.202.50.39|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-07-02 12:49:59--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 103.116.4.197
# Connecting to ibm.box.com (ibm.box.com)|103.116.4.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-07-02 12:50:00--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-07-02 12:50:00--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 103.116.4.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|103.116.4.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!M5sUeB-KStuuYb6vZepW57XN_DLF5YMyS09cxEpTZvmGJF2VevdqAb4MftjQpePSKckZQfsIPGZ8KT7MxKV4J-r-KAJ2zSRNb-tyEQo2lP4kE1J7IPMlCxSUtz1Ha0G2nYhSV9ngBtjZq8UvDRCEld9U11iGlRMaaQW_LTFJzaVeNzTIeQnPAp8SaBwSoRgleJBH916HHb94Hq3KCkMmzwt364TUHaJT3ysPrVglhJ_o6YSEiNtczbZhVtS0dNpF34SpXH4sXev3oIwnWnfqta0Tg1BudcevSsrFHzpfJWl_n6Euvc0NMH77GXqwQuAFtTq43hLQA8iczOlppavZhz_KCqUnmcPgYyk-XuBV-L0HzDzmxL03gwMiMAvyp7ohW2dI1GC6WPMWeKlB2rrplJYs4m8gbZTj4bWg-BMsgdVgO5n0LxVMeSBtm122WbRx3KPbyCR7OOMSmEnrBuxtricgDhnl0_8odrWcVIwwqGTetxRBPNbxjM3guXDHznfON71sL-U1QnhL8lebYztpkFNrNcNAF0LjiKsN5kSSctnK2ha4rOxoxxjQhZC_PWhWz_nKgGhj4bjx1RJE5OByeZJ3M8V-RT5nbIUBCmC139WurpfpTxHUv2brf-LGSI0O4eJuBayy1P6CbRf97nUyqufmrfFWPL_RaCOUv6A_dAZBEikFtEOu33dWZ63FmW_cW1Wk0hqBg8t7xrbJePE0hhwnAQ4mkJ8d0ORipNhIjVwZ2ndH6zw561TSA4t5foRVlr7tYjKbq7lPMbQzyj5YToJAdMNUmEmwkeZnIIpLGWZVh-7kU00LA9J5iEZwfmQJT3gPNr3OuryS_1eTgZ1szxEashOXBq7bVd203tMGxp94wBbAa4zaBsQBjrevpt26-IyGOOsAYg5JuRrnRLOkEvMpYxwdwzfsbcvyZTLUFh1P26AuqdBuJuTHwtVSQZi5FPy6cuSRPrHn4Xt5vvnPC6OBijPAZmv7TI0Tw1veseqcpTE9W0wE6QtdV-V0I3bUcvnHEzgfujZ2xlNMCAx3C7DUmnmHGQC2jx7S3tbW4y2KPVfis_004fR0Ir2IpRpBsY978uWv6SVxX2Y5Sa3R5Kzrpo42LQN6f_x1_LQRL-51T7wlvHI42du1q7U3CYlNipVxLZw29eSSrP6qY7iXX1VKeZtDWDse4iz-w6Qted0Owk9nsNtpwEcGkPBmLiXolw7T89K4Zrmai6Ej2k0Au-ezWroIfv5PlvHyAvUQ96YytbNuOXfCuNPWyRhN4JnQhR5_vwq6OjVCP6vcHnPQtXcV9bL5m5HaSk4cqqYyaMkHG2Ay6LsERxGhlEVLR7kP0PouU-YCnYO0kq_aIB0IY6YqTYoTDMiwpxFGlsFx8tCUA2bI9WDWmQU84zKyJ-s81ar5SbinF2-o4E3p45KcqS--03SkFBsNCmg4G6W7DnGz5Q../download [following]
# --2020-07-02 12:50:02--  https://public.boxcloud.com/d/1/b1!M5sUeB-KStuuYb6vZepW57XN_DLF5YMyS09cxEpTZvmGJF2VevdqAb4MftjQpePSKckZQfsIPGZ8KT7MxKV4J-r-KAJ2zSRNb-tyEQo2lP4kE1J7IPMlCxSUtz1Ha0G2nYhSV9ngBtjZq8UvDRCEld9U11iGlRMaaQW_LTFJzaVeNzTIeQnPAp8SaBwSoRgleJBH916HHb94Hq3KCkMmzwt364TUHaJT3ysPrVglhJ_o6YSEiNtczbZhVtS0dNpF34SpXH4sXev3oIwnWnfqta0Tg1BudcevSsrFHzpfJWl_n6Euvc0NMH77GXqwQuAFtTq43hLQA8iczOlppavZhz_KCqUnmcPgYyk-XuBV-L0HzDzmxL03gwMiMAvyp7ohW2dI1GC6WPMWeKlB2rrplJYs4m8gbZTj4bWg-BMsgdVgO5n0LxVMeSBtm122WbRx3KPbyCR7OOMSmEnrBuxtricgDhnl0_8odrWcVIwwqGTetxRBPNbxjM3guXDHznfON71sL-U1QnhL8lebYztpkFNrNcNAF0LjiKsN5kSSctnK2ha4rOxoxxjQhZC_PWhWz_nKgGhj4bjx1RJE5OByeZJ3M8V-RT5nbIUBCmC139WurpfpTxHUv2brf-LGSI0O4eJuBayy1P6CbRf97nUyqufmrfFWPL_RaCOUv6A_dAZBEikFtEOu33dWZ63FmW_cW1Wk0hqBg8t7xrbJePE0hhwnAQ4mkJ8d0ORipNhIjVwZ2ndH6zw561TSA4t5foRVlr7tYjKbq7lPMbQzyj5YToJAdMNUmEmwkeZnIIpLGWZVh-7kU00LA9J5iEZwfmQJT3gPNr3OuryS_1eTgZ1szxEashOXBq7bVd203tMGxp94wBbAa4zaBsQBjrevpt26-IyGOOsAYg5JuRrnRLOkEvMpYxwdwzfsbcvyZTLUFh1P26AuqdBuJuTHwtVSQZi5FPy6cuSRPrHn4Xt5vvnPC6OBijPAZmv7TI0Tw1veseqcpTE9W0wE6QtdV-V0I3bUcvnHEzgfujZ2xlNMCAx3C7DUmnmHGQC2jx7S3tbW4y2KPVfis_004fR0Ir2IpRpBsY978uWv6SVxX2Y5Sa3R5Kzrpo42LQN6f_x1_LQRL-51T7wlvHI42du1q7U3CYlNipVxLZw29eSSrP6qY7iXX1VKeZtDWDse4iz-w6Qted0Owk9nsNtpwEcGkPBmLiXolw7T89K4Zrmai6Ej2k0Au-ezWroIfv5PlvHyAvUQ96YytbNuOXfCuNPWyRhN4JnQhR5_vwq6OjVCP6vcHnPQtXcV9bL5m5HaSk4cqqYyaMkHG2Ay6LsERxGhlEVLR7kP0PouU-YCnYO0kq_aIB0IY6YqTYoTDMiwpxFGlsFx8tCUA2bI9WDWmQU84zKyJ-s81ar5SbinF2-o4E3p45KcqS--03SkFBsNCmg4G6W7DnGz5Q../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 103.116.4.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|103.116.4.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data’
#
# Geospatial_data     100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2020-07-02 12:50:04 (84.0 MB/s) - ‘Geospatial_data’ saved [2891/2891]

# %% [markdown]
# Merging the two dataframes.

# %%
geodata = pd.read_csv("Geospatial_data")
toronto_geodata = pd.merge(toronto_neighborhood, geodata, how='inner')

toronto_geodata.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# Analysing all the boroughs wich have the word **York** in it.

# %%
york_data = toronto_geodata[toronto_geodata['Borough'].apply(lambda x: 'York' in x)].reset_index(drop = True)

# %% [markdown]
# ## Exploring Places near Neighborhoods
#
# Using Foursquare API Credentials

# %%
CLIENT_ID = 'XR2NWQZAARITNVZDYKA5USHASBG0Y2K4WX3NBCVQBFQZX1HV' 
CLIENT_SECRET = '3QFZVGYG4I25JKUUH5ZFCP30WWEOMJAXAD5CS2XH3O5SYOMH' 
VERSION = '20180604'

# %% [markdown]
# Limiting the results of the API to a 100 per venue, and exploring around the radius of 1000 meters per venue.

# %%
LIMIT = 100
radius = 1000
venues = []

for latitude, longitude in zip(york_data['Latitude'], york_data['Longitude']):
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
    venues.append(requests.get(url).json())

# %%
york_popular = pd.DataFrame(columns=['Postal Code', 'Borough', 'Neighborhood', 'Latitude', 'Longitude', 'Place'])
row_nums = 0

for index, row in enumerate(venues):
    try:
        for i in range(len(row['response']['groups'][0]['items'])):
            york_popular.loc[row_nums] = list(york_data.iloc[index]) + [row['response']['groups'][0]['items'][i]['venue']['categories'][0]['name']]
            row_nums += 1
    except:
        pass
    
york_popular.head()
# Out:
#   Postal Code     Borough Neighborhood   Latitude  Longitude  \
# 0         M3A  North York    Parkwoods  43.753259 -79.329656
# 1         M3A  North York    Parkwoods  43.753259 -79.329656
# 2         M3A  North York    Parkwoods  43.753259 -79.329656
# 3         M3A  North York    Parkwoods  43.753259 -79.329656
# 4         M3A  North York    Parkwoods  43.753259 -79.329656
#
#                   Place
# 0  Caribbean Restaurant
# 1                  Park
# 2                  Café
# 3         Grocery Store
# 4     Fish & Chips Shop

# %% [markdown]
# Now we have the places around each neighborhood with the help of the Foursquare API. After that I try to find the eight most common venues for each neighborhood.

# %%
york_onehot = pd.get_dummies(york_popular['Place'])
york_onehot.insert(0, 'Neighborhood', york_popular['Neighborhood'])

york_grouped = york_onehot.groupby('Neighborhood').mean().reset_index()

york_sorted = pd.DataFrame(columns=['Neighborhood', '1', '2', '3', '4', '5', '6', '7', '8'])
york_sorted['Neighborhood'] = york_grouped['Neighborhood']

for index in range(york_grouped.shape[0]):
    temp = york_grouped.iloc[index, 1:]
    temp_sort = temp.sort_values(ascending=False)
    york_sorted.iloc[index, 1:] = list(temp_sort.index.values[0:8])

york_sorted.head()
# Out:
#                                        Neighborhood                       1  \
# 0   Bathurst Manor, Wilson Heights, Downsview North             Coffee Shop
# 1                                   Bayview Village     Japanese Restaurant
# 2                 Bedford Park, Lawrence Manor East             Coffee Shop
# 3                               Caledonia-Fairbanks                Pharmacy
# 4  Del Ray, Mount Dennis, Keelsdale and Silverthorn  Furniture / Home Store
#
#                     2               3                  4  \
# 0         Pizza Place            Bank  Mobile Phone Shop
# 1                Bank   Grocery Store        Gas Station
# 2  Italian Restaurant  Sandwich Place               Bank
# 3            Bus Stop            Park        Pizza Place
# 4      Discount Store   Grocery Store         Restaurant
#
#                       5                     6                         7  \
# 0              Ski Area         Shopping Mall  Mediterranean Restaurant
# 1            Restaurant                  Park                      Café
# 2            Restaurant              Pharmacy                   Butcher
# 3   Japanese Restaurant  Fast Food Restaurant        Falafel Restaurant
# 4  Fast Food Restaurant        Sandwich Place              Dessert Shop
#
#                      8
# 0              Dog Run
# 1                Trail
# 2                 Café
# 3  Sporting Goods Shop
# 4          Gas Station

# %% [markdown]
# Based on the frequency of venues, I divide them into four different cluster using the KMeans Clustering Method.

# %%
model = KMeans(init='k-means++', n_clusters=4, random_state=1).fit(york_grouped.iloc[:, 1:])

york_sorted.insert(1, 'Cluster Label', model.labels_)

york_final = york_data.copy()
york_final = york_final.join(york_sorted.set_index('Neighborhood'), on='Neighborhood')
york_final.dropna(axis=0, inplace=True)

york_final.head()
# Out:
#   Postal Code     Borough                      Neighborhood   Latitude  \
# 0         M3A  North York                         Parkwoods  43.753259
# 1         M4A  North York                  Victoria Village  43.725882
# 2         M6A  North York  Lawrence Manor, Lawrence Heights  43.718518
# 3         M3B  North York                         Don Mills  43.745906
# 4         M4B   East York   Parkview Hill, Woodbine Gardens  43.706397
#
#    Longitude  Cluster Label               1                       2  \
# 0 -79.329656            3.0            Park           Shopping Mall
# 1 -79.315572            3.0     Coffee Shop            Hockey Arena
# 2 -79.464763            0.0  Clothing Store  Furniture / Home Store
# 3 -79.352188            0.0     Coffee Shop              Restaurant
# 4 -79.309937            3.0     Pizza Place    Gym / Fitness Center
#
#                       3                     4                    5  \
# 0              Pharmacy              Bus Stop    Convenience Store
# 1          Intersection            Playground          Pizza Place
# 2           Coffee Shop  Fast Food Restaurant  Fried Chicken Joint
# 3   Japanese Restaurant                   Gym         Burger Joint
# 4  Fast Food Restaurant               Brewery               Bakery
#
#                        6                 7                     8
# 0     Chinese Restaurant    Discount Store  Fast Food Restaurant
# 1                   Park              Café   Sporting Goods Shop
# 2  Vietnamese Restaurant  Sushi Restaurant            Restaurant
# 3            Supermarket  Asian Restaurant                  Bank
# 4               Pharmacy         Pet Store           Coffee Shop

# %% [markdown]
# ## Visualization
#
# All the clusters made are visualized on the map below using the Folium library.

# %%
latitude = 43.6957
longitude = -79.4504

york_map = folium.Map(location=[latitude, longitude], zoom_start=11)

colors = ['red', 'blue', 'green', 'yellow']

for lat, lon, neighborhood, cluster in zip(york_final['Latitude'], york_final['Longitude'], york_final['Neighborhood'], york_final['Cluster Label']):
    label = folium.Popup(str(neighborhood))
    folium.CircleMarker(
        [lat, lon], 
        radius=5,
        popup=label,
        color=colors[int(cluster)],
        fill=True, 
        fill_opacity=0.7
    ).add_to(york_map)
    
display(york_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examiming the clusters

# %% [markdown]
# The clusters formed can be analysed indivisually.

# %%
york_final[york_final['Cluster Label'] == 0]
# Out:
#    Postal Code     Borough                                      Neighborhood  \
# 2          M6A  North York                  Lawrence Manor, Lawrence Heights
# 3          M3B  North York                                         Don Mills
# 5          M6B  North York                                         Glencairn
# 6          M3C  North York                                         Don Mills
# 9          M6E        York                               Caledonia-Fairbanks
# 10         M4G   East York                                           Leaside
# 12         M3H  North York   Bathurst Manor, Wilson Heights, Downsview North
# 14         M2J  North York                      Fairview, Henry Farm, Oriole
# 17         M2K  North York                                   Bayview Village
# 22         M9L  North York                                     Humber Summit
# 25         M5M  North York                 Bedford Park, Lawrence Manor East
# 26         M6M        York  Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 28         M2N  North York                       Willowdale, Willowdale East
#
#      Latitude  Longitude  Cluster Label                       1  \
# 2   43.718518 -79.464763            0.0          Clothing Store
# 3   43.745906 -79.352188            0.0             Coffee Shop
# 5   43.709577 -79.445073            0.0           Grocery Store
# 6   43.725900 -79.340923            0.0             Coffee Shop
# 9   43.689026 -79.453512            0.0                Pharmacy
# 10  43.709060 -79.363452            0.0             Coffee Shop
# 12  43.754328 -79.442259            0.0             Coffee Shop
# 14  43.778517 -79.346556            0.0             Coffee Shop
# 17  43.786947 -79.385975            0.0     Japanese Restaurant
# 22  43.756303 -79.565963            0.0             Pizza Place
# 25  43.733283 -79.419750            0.0             Coffee Shop
# 26  43.691116 -79.476013            0.0  Furniture / Home Store
# 28  43.770120 -79.408493            0.0             Coffee Shop
#
#                          2                    3                     4  \
# 2   Furniture / Home Store          Coffee Shop  Fast Food Restaurant
# 3               Restaurant  Japanese Restaurant                   Gym
# 5     Fast Food Restaurant   Italian Restaurant           Gas Station
# 6               Restaurant  Japanese Restaurant                   Gym
# 9                 Bus Stop                 Park           Pizza Place
# 10     Sporting Goods Shop        Grocery Store     Electronics Store
# 12             Pizza Place                 Bank     Mobile Phone Shop
# 14          Clothing Store       Sandwich Place   Japanese Restaurant
# 17                    Bank        Grocery Store           Gas Station
# 22                Pharmacy  Arts & Crafts Store     Electronics Store
# 25      Italian Restaurant       Sandwich Place                  Bank
# 26          Discount Store        Grocery Store            Restaurant
# 28        Ramen Restaurant      Bubble Tea Shop           Pizza Place
#
#                          5                      6                         7  \
# 2      Fried Chicken Joint  Vietnamese Restaurant          Sushi Restaurant
# 3             Burger Joint            Supermarket          Asian Restaurant
# 5                     Park            Coffee Shop               Pizza Place
# 6             Burger Joint            Supermarket          Asian Restaurant
# 9      Japanese Restaurant   Fast Food Restaurant        Falafel Restaurant
# 10  Furniture / Home Store         Sandwich Place                      Bank
# 12                Ski Area          Shopping Mall  Mediterranean Restaurant
# 14              Restaurant                   Bank                    Bakery
# 17              Restaurant                   Park                      Café
# 22      Italian Restaurant          Shopping Mall                      Park
# 25              Restaurant               Pharmacy                   Butcher
# 26    Fast Food Restaurant         Sandwich Place              Dessert Shop
# 28     Japanese Restaurant      Korean Restaurant            Sandwich Place
#
#                        8
# 2             Restaurant
# 3                   Bank
# 5            Fish Market
# 6                   Bank
# 9    Sporting Goods Shop
# 10            Restaurant
# 12               Dog Run
# 14              Pharmacy
# 17                 Trail
# 22                Bakery
# 25                  Café
# 26           Gas Station
# 28  Fast Food Restaurant

# %%
york_final[york_final['Cluster Label'] == 1]
# Out:
#    Postal Code     Borough              Neighborhood  Latitude  Longitude  \
# 19         M2L  North York  York Mills, Silver Hills  43.75749 -79.374714
#
#     Cluster Label     1     2            3                     4  \
# 19            1.0  Park  Pool  Yoga Studio  Fast Food Restaurant
#
#                  5                   6            7                  8
# 19  Farmers Market  Falafel Restaurant  Event Space  Electronics Store

# %%
york_final[york_final['Cluster Label'] == 2]
# Out:
#    Postal Code     Borough      Neighborhood   Latitude  Longitude  \
# 27         M9M  North York  Humberlea, Emery  43.724766 -79.532242
#
#     Cluster Label               1     2                  3             4  \
# 27            2.0  Discount Store  Park  Convenience Store  Intersection
#
#               5                 6            7       8
# 27  Golf Course  Storage Facility  Gas Station  Bakery

# %%
york_final[york_final['Cluster Label'] == 3]
# Out:
#    Postal Code     Borough                              Neighborhood  \
# 0          M3A  North York                                 Parkwoods
# 1          M4A  North York                          Victoria Village
# 4          M4B   East York           Parkview Hill, Woodbine Gardens
# 7          M4C   East York                          Woodbine Heights
# 8          M6C        York                        Humewood-Cedarvale
# 11         M2H  North York                         Hillcrest Village
# 13         M4H   East York                          Thorncliffe Park
# 15         M3J  North York           Northwood Park, York University
# 18         M3K  North York                                 Downsview
# 20         M3L  North York                                 Downsview
# 21         M6L  North York  North Park, Maple Leaf Park, Upwood Park
# 23         M2M  North York                   Willowdale, Newtonbrook
# 24         M3M  North York                                 Downsview
# 29         M3N  North York                                 Downsview
# 30         M6N        York             Runnymede, The Junction North
# 31         M9N        York                                    Weston
# 32         M2P  North York                           York Mills West
# 33         M2R  North York               Willowdale, Willowdale West
#
#      Latitude  Longitude  Cluster Label                       1  \
# 0   43.753259 -79.329656            3.0                    Park
# 1   43.725882 -79.315572            3.0             Coffee Shop
# 4   43.706397 -79.309937            3.0             Pizza Place
# 7   43.695344 -79.318389            3.0                    Park
# 8   43.693781 -79.428191            3.0             Pizza Place
# 11  43.803762 -79.363452            3.0                Pharmacy
# 13  43.705369 -79.349372            3.0             Coffee Shop
# 15  43.767980 -79.487262            3.0  Furniture / Home Store
# 18  43.737473 -79.464763            3.0   Vietnamese Restaurant
# 20  43.739015 -79.506944            3.0   Vietnamese Restaurant
# 21  43.713756 -79.490074            3.0             Coffee Shop
# 23  43.789053 -79.408493            3.0       Korean Restaurant
# 24  43.728496 -79.495697            3.0   Vietnamese Restaurant
# 29  43.761631 -79.520999            3.0   Vietnamese Restaurant
# 30  43.673185 -79.487262            3.0             Coffee Shop
# 31  43.706876 -79.518188            3.0             Coffee Shop
# 32  43.752758 -79.400049            3.0                    Park
# 33  43.782736 -79.442259            3.0                Pharmacy
#
#                        2                     3                 4  \
# 0          Shopping Mall              Pharmacy          Bus Stop
# 1           Hockey Arena          Intersection        Playground
# 4   Gym / Fitness Center  Fast Food Restaurant           Brewery
# 7            Coffee Shop        Sandwich Place      Skating Rink
# 8             Bagel Shop     Convenience Store              Park
# 11           Coffee Shop                  Park       Pizza Place
# 13     Indian Restaurant         Grocery Store       Pizza Place
# 15           Coffee Shop           Pizza Place              Bank
# 18           Coffee Shop                 Hotel       Pizza Place
# 20           Coffee Shop                 Hotel       Pizza Place
# 21    Athletics & Sports           Gas Station              Park
# 23                  Café           Pizza Place              Park
# 24           Coffee Shop                 Hotel       Pizza Place
# 29           Coffee Shop                 Hotel       Pizza Place
# 30           Pizza Place               Brewery              Park
# 31         Train Station     Convenience Store              Bank
# 32           Coffee Shop            Restaurant  Dentist's Office
# 33                  Park           Coffee Shop              Bank
#
#                      5                          6                   7  \
# 0    Convenience Store         Chinese Restaurant      Discount Store
# 1          Pizza Place                       Park                Café
# 4               Bakery                   Pharmacy           Pet Store
# 7          Pizza Place                        Pub          Beer Store
# 8          Coffee Shop              Grocery Store               Field
# 11       Shopping Mall             Sandwich Place  Chinese Restaurant
# 13                 Gym          Afghan Restaurant             Brewery
# 15                 Bar         Falafel Restaurant       Metro Station
# 18         Gas Station                       Park            Pharmacy
# 20         Gas Station                       Park            Pharmacy
# 21  Chinese Restaurant                Pizza Place   Convenience Store
# 23         Coffee Shop  Middle Eastern Restaurant                Bank
# 24         Gas Station                       Park            Pharmacy
# 29         Gas Station                       Park            Pharmacy
# 30   Convenience Store                   Bus Line         Gas Station
# 31            Pharmacy                       Park               Diner
# 32             Dog Run         Chinese Restaurant   French Restaurant
# 33              Bakery                 Baby Store      Discount Store
#
#                               8
# 0          Fast Food Restaurant
# 1           Sporting Goods Shop
# 4                   Coffee Shop
# 7                   Curling Ice
# 8                          Bank
# 11            Korean Restaurant
# 13                 Burger Joint
# 15               Massage Studio
# 18               Discount Store
# 20               Discount Store
# 21           Dim Sum Restaurant
# 23                 Dessert Shop
# 24               Discount Store
# 29               Discount Store
# 30                   Beer Store
# 31                         Café
# 32              Bubble Tea Shop
# 33  Eastern European Restaurant
